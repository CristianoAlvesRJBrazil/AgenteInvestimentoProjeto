# %%
import numpy as np
import pandas as pd
import yfinance as yf

# %%
def obter_dados_ativos(self):
    """Obtém os dados históricos de fechamento dos ativos."""
    dados = yf.download(self.lista_ativos, start=self.inicio_dados, end=self.final_dados)['Close']
    return dados

# %%
#Lista de ativos
lista_ativos = ['ABEV3.SA', 'AZUL4.SA', 'B3SA3.SA', 'BBAS3.SA', 'BBDC3.SA', 'BBDC4.SA', 'BBSE3.SA', 'BRAP4.SA',
                'BRFS3.SA', 'BRKM5.SA', 'CASH3.SA', 'CCRO3.SA', 'CIEL3.SA', 'CMIG4.SA', 'COGN3.SA', 'CPFE3.SA',
                'CPLE6.SA', 'CRFB3.SA', 'CSAN3.SA', 'CSNA3.SA', 'CVCB3.SA', 'CYRE3.SA', 'DIRR3.SA', 'ECOR3.SA',
                'ELET3.SA', 'ELET6.SA', 'EMBR3.SA', 'ENGI11.SA', 'EQTL3.SA', 'EZTC3.SA', 'GGBR4.SA', 'GOAU4.SA',
                'GOLL4.SA', 'GRND3.SA', 'GUAR3.SA', 'HYPE3.SA', 'IRBR3.SA', 'ITSA4.SA', 'ITUB4.SA', 'JBSS3.SA',
                'KLBN11.SA', 'LREN3.SA', 'MGLU3.SA', 'MRFG3.SA', 'MRVE3.SA', 'MULT3.SA', 'NEOE3.SA', 'NTCO3.SA',
                'PCAR3.SA', 'PETR3.SA', 'PETR4.SA', 'POMO4.SA', 'POSI3.SA', 'PRIO3.SA', 'QUAL3.SA', 'RADL3.SA',
                'RAIL3.SA', 'RAPT4.SA', 'RENT3.SA', 'SANB11.SA', 'SBSP3.SA', 'SCAR3.SA', 'SUZB3.SA', 'TAEE11.SA',
                'TCSA3.SA', 'TECN3.SA', 'TEKA3.SA', 'TIMS3.SA', 'TOTS3.SA', 'UGPA3.SA', 'USIM5.SA', 'VALE3.SA',
                'VIVT3.SA', 'WEGE3.SA', 'YDUQ3.SA']

# %%
# Obtém os dados históricos dos ativos
inicio_dados = '2024-01-01'
final_dados = '2024-05-01'
dados = yf.download(lista_ativos, start=inicio_dados, end=final_dados)['Close']
dados
# Out:
# [*********************100%%**********************]  75 of 75 completed
# Ticker      ABEV3.SA  AZUL4.SA  B3SA3.SA   BBAS3.SA  BBDC3.SA   BBDC4.SA  \
# Date
# 2024-01-02     13.71     14.70     14.17  27.379999     15.11  16.750000
# 2024-01-03     13.60     14.21     14.13  27.405001     15.10  16.750000
# 2024-01-04     13.65     13.84     13.72  27.115000     14.90  16.520000
# 2024-01-05     13.60     13.83     13.97  27.440001     15.15  16.879999
# 2024-01-08     13.71     14.89     14.28  27.674999     15.10  16.750000
# ...              ...       ...       ...        ...       ...        ...
# 2024-04-24     12.04      9.59     10.94  27.500000     12.03  13.670000
# 2024-04-25     12.02      9.22     10.83  27.379999     12.01  13.660000
# 2024-04-26     12.01      9.77     11.22  27.379999     12.20  13.880000
# 2024-04-29     12.10     10.03     11.14  27.549999     12.39  14.060000
# 2024-04-30     12.15      9.75     10.79  27.420000     12.36  14.000000
#
# ...

# %%
def calcular_retornos_percentuais(self, dados):
    """Calcula os retornos percentuais diários dos ativos."""
    retornos = dados.pct_change().dropna()
    return retornos

# %%
# Calcula os retornos percentuais diários
retornos_diarios = dados.pct_change().dropna()
retornos_diarios
# Out:
# Ticker      ABEV3.SA  AZUL4.SA  B3SA3.SA  BBAS3.SA  BBDC3.SA  BBDC4.SA  \
# Date
# 2024-01-03 -0.008023 -0.033333 -0.002823  0.000913 -0.000662  0.000000
# 2024-01-04  0.003676 -0.026038 -0.029016 -0.010582 -0.013245 -0.013731
# 2024-01-05 -0.003663 -0.000723  0.018222  0.011986  0.016779  0.021792
# 2024-01-08  0.008088  0.076645  0.022190  0.008564 -0.003300 -0.007701
# 2024-01-09 -0.006565 -0.004701 -0.015406 -0.014995 -0.026490 -0.026866
# ...              ...       ...       ...       ...       ...       ...
# 2024-04-24  0.015177 -0.035211 -0.013526 -0.003623 -0.002488  0.000000
# 2024-04-25 -0.001661 -0.038582 -0.010055 -0.004364 -0.001662 -0.000732
# 2024-04-26 -0.000832  0.059653  0.036011  0.000000  0.015820  0.016105
# 2024-04-29  0.007494  0.026612 -0.007130  0.006209  0.015574  0.012968
# 2024-04-30  0.004132 -0.027916 -0.031418 -0.004719 -0.002421 -0.004267
#
# Ticker      BBSE3.SA  BRAP4.SA  BRFS3.SA  BRKM5.SA  ...  TECN3.SA  TEKA3.SA  \
# ...

# %%
def simular_carteiras(self, num_carteiras=1000, num_ativos=4):
    """Simula carteiras aleatórias com os ativos disponíveis."""
    carteiras = []
    for _ in range(num_carteiras):
        ativos_carteira = np.random.choice(self.lista_ativos, size=num_ativos, replace=False)
        retorno_carteira = self.retornos_ativos[ativos_carteira].mean(axis=1)
        carteiras.append((ativos_carteira, retorno_carteira))
    return carteiras

# %%
# Simular carteira aleatória
num_ativos=4
ativos_carteira = np.random.choice(lista_ativos, size=num_ativos, replace=False)
ativos_carteira
# Out:
# array(['SCAR3.SA', 'ENGI11.SA', 'MGLU3.SA', 'ELET6.SA'], dtype='<U9')

# %%
retorno_carteira = retornos_diarios[ativos_carteira].mean(axis=1)
retorno_carteira
# Out:
# Date
# 2024-01-03   -0.002206
# 2024-01-04   -0.018756
# 2024-01-05   -0.000024
# 2024-01-08    0.018154
# 2024-01-09    0.013883
#                 ...
# 2024-04-24   -0.012968
# 2024-04-25   -0.004772
# 2024-04-26    0.021181
# 2024-04-29    0.000126
# 2024-04-30   -0.004817
# Length: 82, dtype: float64

# %%
num_ativos = 4
num_carteiras = 2
carteiras = []
for _ in range(num_carteiras):
    ativos_carteira = np.random.choice(lista_ativos, size=num_ativos, replace=False)
    retorno_carteira = retornos_diarios[ativos_carteira].mean(axis=1)
    carteiras.append((ativos_carteira, retorno_carteira))

print(carteiras)
# Out:
# [(array(['UGPA3.SA', 'CRFB3.SA', 'CCRO3.SA', 'CPFE3.SA'], dtype='<U9'), Date
# 2024-01-03   -0.000645
# 2024-01-04   -0.010779
# 2024-01-05    0.005189
# 2024-01-08    0.004644
# 2024-01-09   -0.003312
#                 ...
# 2024-04-24   -0.011555
# 2024-04-25    0.003708
# 2024-04-26    0.012451
# 2024-04-29   -0.013161
# 2024-04-30   -0.021895
# Length: 82, dtype: float64), (array(['MGLU3.SA', 'CASH3.SA', 'BBSE3.SA', 'ABEV3.SA'], dtype='<U9'), Date
# 2024-01-03   -0.010837
# 2024-01-04   -0.004414
# 2024-01-05    0.001733
# 2024-01-08    0.016063
# 2024-01-09    0.002141
#                 ...
# 2024-04-24   -0.004848
# 2024-04-25   -0.009932
# 2024-04-26    0.012801
# 2024-04-29    0.005832
# 2024-04-30   -0.018485
# Length: 82, dtype: float64)]

# %%
def calcular_retorno_medio(self, retorno_carteira):
    """Calcula o retorno médio do período."""
    retorno_medio = retorno_carteira.mean()
    return retorno_medio

# %%
retorno_carteira
# Out:
# Date
# 2024-01-03   -0.002206
# 2024-01-04   -0.018756
# 2024-01-05   -0.000024
# 2024-01-08    0.018154
# 2024-01-09    0.013883
#                 ...
# 2024-04-24   -0.012968
# 2024-04-25   -0.004772
# 2024-04-26    0.021181
# 2024-04-29    0.000126
# 2024-04-30   -0.004817
# Length: 82, dtype: float64

# %%
retorno_medio = retorno_carteira.mean()
retorno_medio
# Out:
# -0.0015481702904730312

# %%
def calcular_desvio_padrao(self, retorno_carteira):
    """Calcula o desvio padrão do período."""
    desvio_padrao = retorno_carteira.std()
    return desvio_padrao

# %%
desvio_padrao = retorno_carteira.std()
desvio_padrao
# Out:
# 0.013719419788148531

# %%
def calcular_retorno_acumulado(self, retorno_carteira):
    """Calcula o retorno acumulado do período."""
    retorno_acumulado = (1 + retorno_carteira).cumprod().iloc[-1]
    return retorno_acumulado

# %%
retorno_acumulado = (1 + retorno_carteira).cumprod()
retorno_acumulado
# Out:
# Date
# 2024-01-03    0.997794
# 2024-01-04    0.979079
# 2024-01-05    0.979056
# 2024-01-08    0.996830
# 2024-01-09    1.010670
#                 ...
# 2024-04-24    0.864025
# 2024-04-25    0.859902
# 2024-04-26    0.878116
# 2024-04-29    0.878226
# 2024-04-30    0.873996
# Length: 82, dtype: float64

# %%
retorno_acumulado = (1 + retorno_carteira).cumprod().iloc[-1]
retorno_acumulado
# Out:
# 0.8739960366986902

# %%
def encontrar_carteira_vencedora(self, carteiras, retorno_ibov):
    """Encontra a carteira com o maior retorno acumulado acima do Ibovespa."""
    retorno_acumulado_carteiras = [self.calcular_retorno_acumulado(carteira[1]) for carteira in carteiras]
    def calculo(carteira):
        retorno_carteira = carteira[1]
        return (self.calcular_retorno_medio(retorno_carteira) - retorno_ibov.mean()) * self.calcular_retorno_acumulado(carteira[1])
    carteira_vencedora = max(carteiras, key=calculo)
    return carteira_vencedora, retorno_acumulado_carteiras

# %%
def calcular_retorno_acumulado(retorno_carteira):
    """Calcula o retorno acumulado do período."""
    retorno_acumulado = (1 + retorno_carteira).cumprod().iloc[-1]
    return retorno_acumulado

# %%
retorno_acumulado_carteiras = [calcular_retorno_acumulado(carteira[1]) for carteira in carteiras]
retorno_acumulado_carteiras
# Out:
# [0.9083758772164107, 0.7886331521708956]

# %%
def obter_dados_ibov(self, inicio_dados, final_dados):
    """Obtém os dados históricos de fechamento do Ibovespa."""
    lista_indicador = ['^BVSP']
    ibov = yf.download(lista_indicador, start=inicio_dados, end=final_dados)['Close']
    retorno_ibov = self.calcular_retornos_percentuais(ibov)
    return retorno_ibov

# %%
# Obtém os dados históricos do Ibovespa
lista_indicador = ['^BVSP']
inicio_dados = '2024-01-01'
final_dados = '2024-05-01'
ibov = yf.download(lista_indicador, start=inicio_dados, end=final_dados)['Close']
retorno_ibov = ibov.pct_change().dropna()
retorno_ibov
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Date
# 2024-01-03    0.001032
# 2024-01-04   -0.012105
# 2024-01-05    0.006073
# 2024-01-08    0.003060
# 2024-01-09   -0.007400
#                 ...
# 2024-04-24   -0.003252
# 2024-04-25   -0.000762
# 2024-04-26    0.015083
# 2024-04-29    0.006528
# 2024-04-30   -0.011213
# Name: Close, Length: 82, dtype: float64

# %%
retorno_carteira = carteiras[1][1]
retorno_carteira
# Out:
# Date
# 2024-01-03   -0.010837
# 2024-01-04   -0.004414
# 2024-01-05    0.001733
# 2024-01-08    0.016063
# 2024-01-09    0.002141
#                 ...
# 2024-04-24   -0.004848
# 2024-04-25   -0.009932
# 2024-04-26    0.012801
# 2024-04-29    0.005832
# 2024-04-30   -0.018485
# Length: 82, dtype: float64

# %%
retorno_carteira.mean()
# Out:
# -0.0027522350722655703

# %%
def simular_carteiras(self, num_carteiras=1000, num_ativos=4):
    """Simula carteiras aleatórias com os ativos disponíveis."""
    carteiras = []
    for _ in range(num_carteiras):
        ativos_carteira = np.random.choice(self.lista_ativos, size=num_ativos, replace=False)
        retorno_carteira = self.retornos_ativos[ativos_carteira].mean(axis=1)
        carteiras.append((ativos_carteira, retorno_carteira))
    return carteiras

# %%
# Simular carteira aleatória
num_ativos=4
ativos_carteira_lista = np.random.choice(lista_ativos, size=num_ativos, replace=False)
ativos_carteira_lista
# Out:
# array(['RAIL3.SA', 'TEKA3.SA', 'QUAL3.SA', 'NTCO3.SA'], dtype='<U9')

# %%
#Selecionar colunas do dataframe
ativos_carteira = dados[ativos_carteira_lista]
ativos_carteira
# Out:
# Ticker       RAIL3.SA  TEKA3.SA  QUAL3.SA   NTCO3.SA
# Date
# 2024-01-02  22.250000      8.23      3.23  16.690001
# 2024-01-03  22.379999      8.23      3.28  16.760000
# 2024-01-04  22.400000      8.23      3.14  16.150000
# 2024-01-05  22.650000      8.23      3.28  16.309999
# 2024-01-08  23.639999      8.23      3.32  16.450001
# ...               ...       ...       ...        ...
# 2024-04-24  20.650000     50.00      1.58  16.440001
# 2024-04-25  20.600000     50.00      1.70  16.520000
# 2024-04-26  20.840000     50.00      1.71  16.879999
# 2024-04-29  20.830000     50.00      1.69  16.879999
# 2024-04-30  20.160000     50.00      1.60  16.590000
#
# [83 rows x 4 columns]

# %%
retorno_carteira = retornos_diarios[ativos_carteira_lista].mean(axis=1)
retorno_carteira
# Out:
# Date
# 2024-02-06    0.030465
# 2024-02-07    0.006815
# 2024-02-08   -0.005870
# 2024-02-09   -0.004291
# 2024-02-14   -0.005733
#                 ...
# 2024-05-24    0.001732
# 2024-05-27    0.001832
# 2024-05-28   -0.012431
# 2024-05-29   -0.003178
# 2024-05-31   -0.004764
# Length: 79, dtype: float64

# %%
retorno_acumulado_carteira = (1 + retorno_carteira).cumprod().iloc[-1]
retorno_acumulado_carteira
# Out:
# 1.7620517397418167

# %%
retorno_acumulado_ibov = (1 + retorno_ibov).cumprod().iloc[-1]
retorno_acumulado_ibov
# Out:
# 0.9489589063807012

# %%
retorno_acumulado_carteira > retorno_acumulado_ibov
# Out:
# True

# %%
(retorno_acumulado_carteira / retorno_acumulado_ibov) - 1
# Out:
# 0.8568261785562721

# %%
#!pip install yfinance

import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Função para buscar dados históricos do yfinance
def fetch_historical_data(ticker, period='1y'):
    stock_data = yf.download(ticker, period=period)
    return stock_data['Close']

# Função para prever futuras contagens usando o método de Monte Carlo
def monte_carlo_prediction(prices, num_simulations=1000, num_days=90):
    log_returns = np.log(1 + prices.pct_change())
    mean_return = log_returns.mean()
    std_return = log_returns.std()

    simulations = []

    for _ in range(num_simulations):
        simulation_prices = []
        last_price = prices.iloc[-1]

        for _ in range(num_days):
            next_price = last_price * np.exp(mean_return + std_return * np.random.normal())
            simulation_prices.append(next_price)
            last_price = next_price

        simulations.append(simulation_prices)

    return simulations

# Configurações iniciais
ticker = 'EMBR3.SA'  # Substitua pelo ticker desejado
period = '1y'

# Buscar dados históricos
historical_prices = fetch_historical_data(ticker, period)

# Realizar previsões usando o método de Monte Carlo
num_simulations = 1000
num_days = 90
predicted_prices = monte_carlo_prediction(historical_prices, num_simulations, num_days)

# Plotar os dados históricos e as previsões
plt.figure(figsize=(14, 7))
plt.plot(historical_prices.index, historical_prices, label='Histórico de Preços')

# Adicionar previsões ao gráfico
last_date = historical_prices.index[-1]
future_dates = pd.date_range(start=last_date, periods=num_days+1, inclusive='right')

for simulation in predicted_prices:
    plt.plot(future_dates, simulation, color='red', alpha=0.01)

plt.title(f"Simulação de Monte Carlo para {ticker} - Próximos {num_days} dias")
plt.xlabel("Data")
plt.ylabel("Preço de Fechamento")
plt.legend()
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Função para buscar dados históricos do yfinance
def fetch_historical_data(ticker, inicio_dados, final_dados):
    stock_data = yf.download(ticker, start=inicio_dados, end=final_dados)['Close']
    return stock_data

# Função para prever futuras contagens usando o método de Monte Carlo
def monte_carlo_prediction(prices, num_simulations=1000, num_days=90):
    log_returns = np.log(1 + prices.pct_change())
    mean_return = log_returns.mean()
    std_return = log_returns.std()

    simulations = []

    for _ in range(num_simulations):
        simulation_prices = []
        last_price = prices.iloc[-1]

        for _ in range(num_days):
            next_price = last_price * np.exp(mean_return + std_return * np.random.normal())
            simulation_prices.append(next_price)
            last_price = next_price

        simulations.append(simulation_prices)

    return simulations

def main(ticker, inicio_dados, final_dados):

    # Buscar dados históricos
    historical_prices = fetch_historical_data(ticker, inicio_dados, final_dados)

    # Realizar previsões usando o método de Monte Carlo
    num_simulations = 1000
    num_days = 60
    predicted_prices = monte_carlo_prediction(historical_prices, num_simulations, num_days)

    # Plotar os dados históricos e as previsões
    plt.figure(figsize=(14, 7))
    plt.plot(historical_prices.index, historical_prices, label='Histórico de Preços')

    # Adicionar previsões ao gráfico
    last_date = historical_prices.index[-1]
    future_dates = pd.date_range(start=last_date, periods=num_days+1, inclusive='right')

    for simulation in predicted_prices:
        plt.plot(future_dates, simulation, color='red', alpha=0.01)

    plt.title(f"Simulação de Monte Carlo para {ticker} - Próximos {num_days} dias")
    plt.xlabel("Data")
    plt.ylabel("Preço de Fechamento")
    plt.legend()
    plt.show()

if __name__ == "__main__":

    # Configurações iniciais
    ticker = ['VALE3.SA']  # Substitua pelo ticker desejado
    inicio_dados = '2023-08-01'
    final_dados = '2024-01-01'
    main(ticker, inicio_dados, final_dados)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
#pip install numpy pandas yfinance matplotlib tensorflow

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

class StockPredictor:
    def __init__(self, ticker, data_inicio, data_fim, janela=120):
        self.ticker = ticker
        self.data_inicio = data_inicio
        self.data_fim = data_fim
        self.janela = janela
        self.dados = self.obter_dados()
        self.scaler = MinMaxScaler(feature_range=(0, 1))
        self.modelo = None

    def obter_dados(self):
        """Baixa dados históricos de preços ajustados do ativo."""
        dados = yf.download(self.ticker, start=self.data_inicio, end=self.data_fim)['Adj Close']
        return dados

    def preprocessar_dados(self):
        """Preprocessa os dados para serem usados na rede neural."""
        dados_escala = self.scaler.fit_transform(self.dados.values.reshape(-1, 1))

        X_train, y_train = [], []
        for i in range(self.janela, len(dados_escala)):
            X_train.append(dados_escala[i - self.janela:i, 0])
            y_train.append(dados_escala[i, 0])

        X_train, y_train = np.array(X_train), np.array(y_train)
        X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

        return X_train, y_train

    def construir_modelo(self):
        """Constrói e compila o modelo LSTM."""
        modelo = Sequential()
        modelo.add(LSTM(units=100, return_sequences=True, input_shape=(self.janela, 1)))
        modelo.add(Dropout(0.2))
        modelo.add(LSTM(units=100, return_sequences=False))
        modelo.add(Dropout(0.2))
        modelo.add(Dense(units=1))

        modelo.compile(optimizer='adam', loss='mean_squared_error')
        return modelo

    def treinar_modelo(self, X_train, y_train, epochs=25, batch_size=32):
        """Treina o modelo LSTM."""
        self.modelo = self.construir_modelo()
        self.modelo.fit(X_train, y_train, epochs=epochs, batch_size=batch_size)

    def prever_precos_futuros(self, dias_previsao=30):
        """Prevê os preços futuros começando do último preço conhecido."""
        sequencia_recente = self.dados[-self.janela:].values
        sequencia_recente_escala = self.scaler.transform(sequencia_recente.reshape(-1, 1))

        previsoes = []
        for _ in range(dias_previsao):
            X_input = np.array(sequencia_recente_escala[-self.janela:]).reshape(1, self.janela, 1)
            predicao_escala = self.modelo.predict(X_input)
            predicao = self.scaler.inverse_transform(predicao_escala)
            previsoes.append(predicao[0, 0])

            # Adiciona a previsão ao final da sequência e remove o primeiro elemento
            sequencia_recente_escala = np.append(sequencia_recente_escala, predicao_escala, axis=0)

        return previsoes

    def plotar_previsao(self, dias_previsao=30):
        """Plota os preços reais e previstos."""
        previsoes = self.prever_precos_futuros(dias_previsao)
        plt.figure(figsize=(14, 7))
        plt.plot(self.dados.values, color='blue', label='Preço Real')
        plt.plot(range(len(self.dados), len(self.dados) + dias_previsao), previsoes, color='red', label='Previsão de Preço')
        plt.title(f'Previsão de Preços para {self.ticker}')
        plt.xlabel('Data')
        plt.ylabel('Preço')
        plt.legend()
        plt.show()

# Parâmetros de entrada
ticker = 'EMBR3.SA'  # Substitua pelo ticker desejado
data_inicio = '2023-06-09'
data_fim = '2024-06-09'

# Criação do previsor de ações
previsor = StockPredictor(ticker, data_inicio, data_fim)

# Preprocessar dados e treinar o modelo
X_train, y_train = previsor.preprocessar_dados()
previsor.treinar_modelo(X_train, y_train)

# Prever preços futuros e plotar os resultados
previsor.plotar_previsao(dias_previsao=60)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Epoch 1/25
# 5/5 [==============================] - 7s 154ms/step - loss: 0.0952
# Epoch 2/25
# 5/5 [==============================] - 1s 161ms/step - loss: 0.0227
# Epoch 3/25
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0249
# Epoch 4/25
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0110
# Epoch 5/25
# 5/5 [==============================] - 1s 155ms/step - loss: 0.0103
# Epoch 6/25
# 5/5 [==============================] - 1s 161ms/step - loss: 0.0120
# Epoch 7/25
# 5/5 [==============================] - 1s 158ms/step - loss: 0.0107
# Epoch 8/25
# 5/5 [==============================] - 1s 161ms/step - loss: 0.0084
# Epoch 9/25
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0088
# Epoch 10/25
# 5/5 [==============================] - 1s 158ms/step - loss: 0.0097
# Epoch 11/25
# 5/5 [==============================] - 1s 160ms/step - loss: 0.0058
# Epoch 12/25
# ...

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

class StockPredictor:
    def __init__(self, ticker, data_inicio, data_fim, janela=90):
        self.ticker = ticker
        self.data_inicio = data_inicio
        self.data_fim = data_fim
        self.janela = janela
        self.dados = self.obter_dados()
        self.scaler = MinMaxScaler(feature_range=(0, 1))
        self.modelo = None

    def obter_dados(self):
        """Baixa dados históricos de preços ajustados do ativo."""
        dados = yf.download(self.ticker, start=self.data_inicio, end=self.data_fim)['Adj Close']
        return dados

    def preprocessar_dados(self):
        """Preprocessa os dados para serem usados na rede neural."""
        dados_escala = self.scaler.fit_transform(self.dados.values.reshape(-1, 1))

        X_train, y_train = [], []
        for i in range(self.janela, len(dados_escala)):
            X_train.append(dados_escala[i - self.janela:i, 0])
            y_train.append(dados_escala[i, 0])

        X_train, y_train = np.array(X_train), np.array(y_train)
        X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

        return X_train, y_train

    def construir_modelo(self):
        """Constrói e compila o modelo LSTM."""
        modelo = Sequential()
        modelo.add(LSTM(units=100, return_sequences=True, input_shape=(self.janela, 1)))
        modelo.add(Dropout(0.2))
        modelo.add(LSTM(units=100, return_sequences=False))
        modelo.add(Dropout(0.2))
        modelo.add(Dense(units=1))

        modelo.compile(optimizer='adam', loss='mean_squared_error')
        return modelo

    def treinar_modelo(self, X_train, y_train, epochs=25, batch_size=32):
        """Treina o modelo LSTM."""
        self.modelo = self.construir_modelo()
        self.modelo.fit(X_train, y_train, epochs=epochs, batch_size=batch_size)

    def prever_precos_futuros(self, dias_previsao=30):
        """Prevê os preços futuros começando do último preço conhecido."""
        sequencia_recente = self.dados[-self.janela:].values
        sequencia_recente_escala = self.scaler.transform(sequencia_recente.reshape(-1, 1))

        previsoes = []
        for _ in range(dias_previsao):
            X_input = np.array(sequencia_recente_escala[-self.janela:]).reshape(1, self.janela, 1)
            predicao_escala = self.modelo.predict(X_input)
            predicao = self.scaler.inverse_transform(predicao_escala)
            previsoes.append(predicao[0, 0])

            # Adiciona a previsão ao final da sequência e remove o primeiro elemento
            sequencia_recente_escala = np.append(sequencia_recente_escala, predicao_escala, axis=0)

        return previsoes

    def simular_monte_carlo(self, dias_previsao=30, num_simulacoes=1000):
        """Executa Simulação de Monte Carlo baseada nas previsões da RNN."""
        previsao_base = self.prever_precos_futuros(dias_previsao)
        retorno_diario = np.diff(np.log(previsao_base))  # Calcular retornos log diários
        media_ret = np.mean(retorno_diario)
        std_ret = np.std(retorno_diario)

        previsoes_mc = np.zeros((num_simulacoes, dias_previsao))
        ultimo_preco_conhecido = self.dados.values[-1]  # Último preço conhecido

        for i in range(num_simulacoes):
            simulacao = []
            ultimo_preco = ultimo_preco_conhecido
            for _ in range(dias_previsao):
                variacao = np.random.normal(media_ret, std_ret)
                ultimo_preco = ultimo_preco * np.exp(variacao)
                simulacao.append(ultimo_preco)
            previsoes_mc[i, :] = simulacao

        return previsoes_mc

    def plotar_previsao_com_mc(self, dias_previsao=30, num_simulacoes=1000):
        """Plota os preços reais, previstos e as simulações de Monte Carlo."""
        previsao_base = self.prever_precos_futuros(dias_previsao)
        previsoes_mc = self.simular_monte_carlo(dias_previsao, num_simulacoes)

        plt.figure(figsize=(14, 7))
        plt.plot(self.dados.values, color='blue', label='Preço Real')
        plt.plot(range(len(self.dados), len(self.dados) + dias_previsao), previsao_base, color='red', label='Previsão de Preço')

        # Plotar as simulações de Monte Carlo
        for sim in previsoes_mc:
            plt.plot(range(len(self.dados), len(self.dados) + dias_previsao), sim, color='gray', alpha=0.005)

        plt.title(f'Previsão de Preços para {self.ticker} com Monte Carlo')
        plt.xlabel('Data')
        plt.ylabel('Preço')
        plt.legend()
        plt.show()

# Parâmetros de entrada
ticker = 'EMBR3.SA'  # Substitua pelo ticker desejado
data_inicio = '2023-01-01'
data_fim = '2024-04-01'

# Criação do previsor de ações
previsor = StockPredictor(ticker, data_inicio, data_fim)

# Preprocessar dados e treinar o modelo
X_train, y_train = previsor.preprocessar_dados()
previsor.treinar_modelo(X_train, y_train)

# Prever preços futuros e plotar os resultados com Monte Carlo
previsor.plotar_previsao_com_mc(dias_previsao=60, num_simulacoes=1000)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Epoch 1/25
# 7/7 [==============================] - 5s 137ms/step - loss: 0.0660
# Epoch 2/25
# 7/7 [==============================] - 1s 134ms/step - loss: 0.0134
# Epoch 3/25
# 7/7 [==============================] - 1s 132ms/step - loss: 0.0095
# Epoch 4/25
# 7/7 [==============================] - 1s 162ms/step - loss: 0.0081
# Epoch 5/25
# 7/7 [==============================] - 1s 211ms/step - loss: 0.0054
# Epoch 6/25
# 7/7 [==============================] - 2s 235ms/step - loss: 0.0045
# Epoch 7/25
# 7/7 [==============================] - 1s 157ms/step - loss: 0.0038
# Epoch 8/25
# 7/7 [==============================] - 1s 134ms/step - loss: 0.0040
# Epoch 9/25
# 7/7 [==============================] - 1s 134ms/step - loss: 0.0037
# Epoch 10/25
# 7/7 [==============================] - 1s 136ms/step - loss: 0.0043
# Epoch 11/25
# 7/7 [==============================] - 1s 133ms/step - loss: 0.0040
# Epoch 12/25
# ...

# %%
# Importação das bibliotecas necessárias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# Função para carregar os dados
def load_data(stock_symbol, start_date, end_date):
    from pandas_datareader import data as pdr
    import yfinance as yf
    yf.pdr_override()
    df = pdr.get_data_yahoo(stock_symbol, start=start_date, end=end_date)
    return df

# Função para preparar os dados para o modelo LSTM
def prepare_data(df, lookback=60):
    data = df['Close'].values
    data = data.reshape(-1, 1)
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(data)

    X, y = [], []
    for i in range(lookback, len(scaled_data)):
        X.append(scaled_data[i-lookback:i, 0])
        y.append(scaled_data[i, 0])
    X, y = np.array(X), np.array(y)
    X = np.reshape(X, (X.shape[0], X.shape[1], 1))

    return X, y, scaler, scaled_data

# Função para construir o modelo LSTM
def build_model(input_shape):
    model = Sequential()
    model.add(LSTM(units=100, return_sequences=True, input_shape=input_shape))
    model.add(Dropout(0.2))
    model.add(LSTM(units=100, return_sequences=False))
    model.add(Dropout(0.2))
    model.add(Dense(units=1))
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')
    return model

# Função para prever preços futuros
def forecast_future_prices(model, last_sequence, num_predictions, scaler):
    future_predictions = []
    current_sequence = last_sequence

    for _ in range(num_predictions):
        prediction = model.predict(current_sequence)
        future_predictions.append(prediction[0, 0])

        # Remover o primeiro valor da sequência e adicionar a previsão no final
        current_sequence = np.append(current_sequence[:, 1:, :], prediction.reshape(1, 1, 1), axis=1)

    future_predictions = np.array(future_predictions)
    future_predictions = scaler.inverse_transform(future_predictions.reshape(-1, 1))

    return future_predictions

# Função principal para treinar e avaliar o modelo
def main(stock_symbol, start_date, end_date, forecast_days=60, epochs=25, batch_size=32):
    df = load_data(stock_symbol, start_date, end_date)
    train_size = int(len(df) * 0.8)
    train_df = df[:train_size]
    test_df = df[train_size:]

    X_train, y_train, scaler, scaled_data = prepare_data(train_df)
    X_test, y_test, _, _ = prepare_data(test_df)

    model = build_model((X_train.shape[1], 1))
    model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test))

    # Previsão de preços futuros
    last_sequence = scaled_data[-X_train.shape[1]:].reshape(1, X_train.shape[1], 1)
    future_predictions = forecast_future_prices(model, last_sequence, forecast_days, scaler)

    # Visualização
    plt.figure(figsize=(14, 5))
    plt.plot(df['Close'].values, label='Preços Reais')
    plt.plot(range(len(df), len(df) + forecast_days), future_predictions, label='Previsões Futuras', color='red')
    plt.axvline(x=len(df), color='green', linestyle='--', label='Início das Previsões Futuras')
    plt.legend()
    plt.show()

# Configurações do usuário
stock_symbol = 'EMBR3.SA'
start_date = '2023-01-01'
end_date = '2024-04-01'
forecast_days = 60
epochs = 25
batch_size = 32

main(stock_symbol, start_date, end_date)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Epoch 1/25
# 6/6 [==============================] - 7s 322ms/step - loss: 0.1220 - val_loss: 0.0137
# Epoch 2/25
# 6/6 [==============================] - 1s 110ms/step - loss: 0.0365 - val_loss: 0.1848
# Epoch 3/25
# 6/6 [==============================] - 1s 107ms/step - loss: 0.0277 - val_loss: 0.1451
# Epoch 4/25
# 6/6 [==============================] - 1s 98ms/step - loss: 0.0148 - val_loss: 0.0381
# Epoch 5/25
# 6/6 [==============================] - 1s 107ms/step - loss: 0.0149 - val_loss: 0.0687
# Epoch 6/25
# 6/6 [==============================] - 1s 99ms/step - loss: 0.0135 - val_loss: 0.0999
# Epoch 7/25
# 6/6 [==============================] - 1s 95ms/step - loss: 0.0122 - val_loss: 0.0533
# Epoch 8/25
# 6/6 [==============================] - 1s 99ms/step - loss: 0.0120 - val_loss: 0.0375
# Epoch 9/25
# 6/6 [==============================] - 1s 96ms/step - loss: 0.0105 - val_loss: 0.0587
# Epoch 10/25
# ...

# %%
# Importação das bibliotecas necessárias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# Função para carregar os dados
def load_data(stock_symbol, start_date, end_date):
    from pandas_datareader import data as pdr
    import yfinance as yf
    yf.pdr_override()
    df = pdr.get_data_yahoo(stock_symbol, start=start_date, end=end_date)
    return df

# Função para preparar os dados para o modelo LSTM
def prepare_data(df, lookback=60):
    data = df['Close'].values
    data = data.reshape(-1, 1)
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(data)

    X, y = [], []
    for i in range(lookback, len(scaled_data)):
        X.append(scaled_data[i-lookback:i, 0])
        y.append(scaled_data[i, 0])
    X, y = np.array(X), np.array(y)
    X = np.reshape(X, (X.shape[0], X.shape[1], 1))

    return X, y, scaler, scaled_data

# Função para construir o modelo LSTM
def build_model(input_shape):
    model = Sequential()
    model.add(LSTM(units=100, return_sequences=True, input_shape=input_shape))
    model.add(Dropout(0.2))
    model.add(LSTM(units=100, return_sequences=False))
    model.add(Dropout(0.2))
    model.add(Dense(units=1))
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')
    return model

# Função para prever preços futuros
def forecast_future_prices(model, last_sequence, num_predictions, scaler):
    future_predictions = []
    current_sequence = last_sequence

    for _ in range(num_predictions):
        # Faz a previsão
        prediction = model.predict(current_sequence)
        future_predictions.append(prediction[0, 0])

        # Atualiza a sequência com a previsão
        current_sequence = np.append(current_sequence[:, 1:, :], prediction.reshape(1, 1, 1), axis=1)

    # Converte previsões para valores originais
    future_predictions = np.array(future_predictions)
    future_predictions = scaler.inverse_transform(future_predictions.reshape(-1, 1))

    return future_predictions

# Função principal para treinar e avaliar o modelo
def main(stock_symbol, start_date, end_date, forecast_days=60, epochs=25, batch_size=32):
    df = load_data(stock_symbol, start_date, end_date)
    train_size = int(len(df) * 0.8)
    train_df = df[:train_size]
    test_df = df[train_size:]

    X_train, y_train, scaler, scaled_data = prepare_data(train_df)
    X_test, y_test, _, _ = prepare_data(test_df)

    model = build_model((X_train.shape[1], 1))
    model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test))

    # Último preço da série para iniciar as previsões futuras
    last_sequence = scaled_data[-X_train.shape[1]:].reshape(1, X_train.shape[1], 1)
    future_predictions = forecast_future_prices(model, last_sequence, forecast_days, scaler)

    # Visualização
    plt.figure(figsize=(14, 5))
    plt.plot(df['Close'].values, label='Preços Reais', color='blue')
    plt.plot(range(len(df), len(df) + forecast_days), future_predictions, label='Previsões Futuras', color='red')
    plt.axvline(x=len(df), color='green', linestyle='--', label='Início das Previsões Futuras')
    plt.legend()
    plt.xlabel('Dias')
    plt.ylabel('Preço de Fechamento')
    plt.title(f'Previsão de Preços de {stock_symbol}')
    plt.show()

# Configurações do usuário
stock_symbol = 'EMBR3.SA'
start_date = '2023-01-01'
end_date = '2024-04-01'
forecast_days = 60
epochs = 25
batch_size = 32

main(stock_symbol, start_date, end_date)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Epoch 1/25
# 6/6 [==============================] - 7s 302ms/step - loss: 0.0808 - val_loss: 0.0682
# Epoch 2/25
# 6/6 [==============================] - 1s 100ms/step - loss: 0.0219 - val_loss: 0.2204
# Epoch 3/25
# 6/6 [==============================] - 1s 99ms/step - loss: 0.0208 - val_loss: 0.0730
# Epoch 4/25
# 6/6 [==============================] - 1s 110ms/step - loss: 0.0181 - val_loss: 0.0621
# Epoch 5/25
# 6/6 [==============================] - 1s 99ms/step - loss: 0.0145 - val_loss: 0.1028
# Epoch 6/25
# 6/6 [==============================] - 1s 105ms/step - loss: 0.0125 - val_loss: 0.0670
# Epoch 7/25
# 6/6 [==============================] - 1s 110ms/step - loss: 0.0117 - val_loss: 0.0380
# Epoch 8/25
# 6/6 [==============================] - 1s 104ms/step - loss: 0.0117 - val_loss: 0.0620
# Epoch 9/25
# 6/6 [==============================] - 1s 104ms/step - loss: 0.0106 - val_loss: 0.0367
# ...

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

class StockPredictor:
    def __init__(self, ticker, data_inicio, data_fim, janela=90):
        self.ticker = ticker
        self.data_inicio = data_inicio
        self.data_fim = data_fim
        self.janela = janela
        self.dados = self.obter_dados()
        self.scaler = MinMaxScaler(feature_range=(0, 1))
        self.modelo = None

    def obter_dados(self):
        """Baixa dados históricos de preços ajustados do ativo."""
        dados = yf.download(self.ticker, start=self.data_inicio, end=self.data_fim)['Close']
        return dados

    def preprocessar_dados(self):
        """Preprocessa os dados para serem usados na rede neural."""
        dados_escala = self.scaler.fit_transform(self.dados.values.reshape(-1, 1))

        X_train, y_train = [], []
        for i in range(self.janela, len(dados_escala)):
            X_train.append(dados_escala[i - self.janela:i, 0])
            y_train.append(dados_escala[i, 0])

        X_train, y_train = np.array(X_train), np.array(y_train)
        X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

        return X_train, y_train

    def construir_modelo(self):
        """Constrói e compila o modelo LSTM."""
        modelo = Sequential()
        modelo.add(LSTM(units=100, return_sequences=True, input_shape=(self.janela, 1)))
        modelo.add(Dropout(0.2))
        modelo.add(LSTM(units=100, return_sequences=False))
        modelo.add(Dropout(0.2))
        modelo.add(Dense(units=1))

        modelo.compile(optimizer='adam', loss='mean_squared_error')
        return modelo

    def treinar_modelo(self, X_train, y_train, epochs=10, batch_size=32):
        """Treina o modelo LSTM."""
        self.modelo = self.construir_modelo()
        self.modelo.fit(X_train, y_train, epochs=epochs, batch_size=batch_size)

    def prever_precos_futuros(self, dias_previsao=30):
        """Prevê os preços futuros começando do último preço conhecido."""
        sequencia_recente = self.dados[-self.janela:].values
        sequencia_recente_escala = self.scaler.transform(sequencia_recente.reshape(-1, 1))

        previsoes = []
        for _ in range(dias_previsao):
            X_input = np.array(sequencia_recente_escala[-self.janela:]).reshape(1, self.janela, 1)
            predicao_escala = self.modelo.predict(X_input)
            predicao = self.scaler.inverse_transform(predicao_escala)
            previsoes.append(predicao[0, 0])

            # Adiciona a previsão ao final da sequência e remove o primeiro elemento
            sequencia_recente_escala = np.append(sequencia_recente_escala, predicao_escala, axis=0)

        return previsoes

    def simular_monte_carlo(self, dias_previsao=30, num_simulacoes=1000):
        """Executa Simulação de Monte Carlo baseada nas previsões da RNN."""
        previsao_base = self.prever_precos_futuros(dias_previsao)
        retorno_diario = np.diff(np.log(previsao_base))  # Calcular retornos log diários
        media_ret = np.mean(retorno_diario)
        std_ret = np.std(retorno_diario)

        previsoes_mc = np.zeros((num_simulacoes, dias_previsao))
        ultimo_preco_conhecido = self.dados.values[-1]  # Último preço conhecido

        for i in range(num_simulacoes):
            simulacao = []
            ultimo_preco = ultimo_preco_conhecido
            for _ in range(dias_previsao):
                variacao = np.random.normal(media_ret, std_ret)
                ultimo_preco = ultimo_preco * np.exp(variacao)
                simulacao.append(ultimo_preco)
            previsoes_mc[i, :] = simulacao

        return previsoes_mc

    def plotar_previsao_com_mc(self, dias_previsao=30, num_simulacoes=1000):
        """Plota os preços reais, previstos e as simulações de Monte Carlo."""
        previsao_base = self.prever_precos_futuros(dias_previsao)
        previsoes_mc = self.simular_monte_carlo(dias_previsao, num_simulacoes)

        plt.figure(figsize=(14, 7))
        plt.plot(self.dados.values, color='blue', label='Preço Real')
        plt.plot(range(len(self.dados), len(self.dados) + dias_previsao), previsao_base, color='red', label='Previsão de Preço')

        # Plotar as simulações de Monte Carlo
        for sim in previsoes_mc:
            plt.plot(range(len(self.dados), len(self.dados) + dias_previsao), sim, color='gray', alpha=0.005)

        plt.title(f'Previsão de Preços para {self.ticker} com Monte Carlo')
        plt.xlabel('Data')
        plt.ylabel('Preço')
        plt.legend()
        plt.show()

# Parâmetros de entrada
ticker = 'VALE3.SA'  # Substitua pelo ticker desejado
data_inicio = '2022-10-01'
data_fim = '2024-01-01'

# Criação do previsor de ações
previsor = StockPredictor(ticker, data_inicio, data_fim)

# Preprocessar dados e treinar o modelo
X_train, y_train = previsor.preprocessar_dados()
previsor.treinar_modelo(X_train, y_train)

# Prever preços futuros e plotar os resultados com Monte Carlo
previsor.plotar_previsao_com_mc(dias_previsao=60, num_simulacoes=1000)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Epoch 1/10
# 7/7 [==============================] - 5s 127ms/step - loss: 0.0451
# Epoch 2/10
# 7/7 [==============================] - 1s 128ms/step - loss: 0.0091
# Epoch 3/10
# 7/7 [==============================] - 1s 129ms/step - loss: 0.0069
# Epoch 4/10
# 7/7 [==============================] - 1s 126ms/step - loss: 0.0070
# Epoch 5/10
# 7/7 [==============================] - 1s 130ms/step - loss: 0.0058
# Epoch 6/10
# 7/7 [==============================] - 1s 170ms/step - loss: 0.0055
# Epoch 7/10
# 7/7 [==============================] - 1s 208ms/step - loss: 0.0054
# Epoch 8/10
# 7/7 [==============================] - 2s 223ms/step - loss: 0.0050
# Epoch 9/10
# 7/7 [==============================] - 1s 128ms/step - loss: 0.0043
# Epoch 10/10
# ...
# 1/1 [==============================] - 0s 45ms/step

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import LearningRateScheduler

class StockPredictor:
    def __init__(self, ticker, data_inicio, data_fim, janela=180):
        self.ticker = ticker
        self.data_inicio = data_inicio
        self.data_fim = data_fim
        self.janela = janela
        self.dados = self.obter_dados()
        self.scaler = MinMaxScaler(feature_range=(0, 1))
        self.modelo = None

    def obter_dados(self):
        """Baixa dados históricos dos preços de fechamento do ativo."""
        dados = yf.download(self.ticker, start=self.data_inicio, end=self.data_fim)['Close']
        return dados

    def preprocessar_dados(self):
        """Preprocessa os dados para serem usados na rede neural."""
        dados_escala = self.scaler.fit_transform(self.dados.values.reshape(-1, 1))

        X_train, y_train = [], []
        for i in range(self.janela, len(dados_escala)):
            X_train.append(dados_escala[i - self.janela:i, 0])
            y_train.append(dados_escala[i, 0])

        X_train, y_train = np.array(X_train), np.array(y_train)
        X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

        return X_train, y_train

    def construir_modelo(self):
        """Constrói e compila o modelo LSTM."""
        modelo = Sequential()
        modelo.add(LSTM(units=100, return_sequences=True, input_shape=(self.janela, 1)))
        modelo.add(Dropout(0.2))
        modelo.add(LSTM(units=300, return_sequences=False))
        modelo.add(Dropout(0.2))
        modelo.add(Dense(units=1))

        modelo.compile(optimizer='adam', loss='mean_squared_error')
        return modelo

    def scheduler(self, epoch, lr):
        """Função para ajustar a taxa de aprendizagem conforme o número de épocas."""
        if epoch < 10:
            return lr
        else:
            return lr * np.exp(-0.1)

    def treinar_modelo(self, X_train, y_train, epochs=20, batch_size=64):
        """Treina o modelo LSTM."""
        self.modelo = self.construir_modelo()
        lr_scheduler = LearningRateScheduler(self.scheduler)
        self.modelo.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, callbacks=[lr_scheduler])

    def prever_precos_futuros(self, dias_previsao=60):
        """Prevê os preços futuros começando do último preço conhecido."""
        sequencia_recente = self.dados[-self.janela:].values
        sequencia_recente_escala = self.scaler.transform(sequencia_recente.reshape(-1, 1))

        previsoes = []
        for _ in range(dias_previsao):
            X_input = np.array(sequencia_recente_escala[-self.janela:]).reshape(1, self.janela, 1)
            predicao_escala = self.modelo.predict(X_input)
            predicao = self.scaler.inverse_transform(predicao_escala)
            previsoes.append(predicao[0, 0])

            # Adiciona a previsão ao final da sequência e remove o primeiro elemento
            sequencia_recente_escala = np.append(sequencia_recente_escala, predicao_escala, axis=0)

        return previsoes

    def simular_monte_carlo(self, dias_previsao=60, num_simulacoes=1000):
        """Executa Simulação de Monte Carlo baseada nas previsões da RNN."""
        previsao_base = self.prever_precos_futuros(dias_previsao)
        retorno_diario = np.diff(np.log(previsao_base))  # Calcular retornos log diários
        media_ret = np.mean(retorno_diario)
        std_ret = np.std(retorno_diario)

        previsoes_mc = np.zeros((num_simulacoes, dias_previsao))
        ultimo_preco_conhecido = self.dados.values[-1]  # Último preço conhecido

        for i in range(num_simulacoes):
            simulacao = []
            ultimo_preco = ultimo_preco_conhecido
            for _ in range(dias_previsao):
                variacao = np.random.normal(media_ret, std_ret)
                ultimo_preco = ultimo_preco * np.exp(variacao)
                simulacao.append(ultimo_preco)
            previsoes_mc[i, :] = simulacao

        return previsoes_mc

    def plotar_previsao_com_mc(self, dias_previsao=60, num_simulacoes=1000):
        """Plota os preços reais, previstos e as simulações de Monte Carlo."""
        previsao_base = self.prever_precos_futuros(dias_previsao)
        previsoes_mc = self.simular_monte_carlo(dias_previsao, num_simulacoes)

        plt.figure(figsize=(14, 7))
        plt.plot(self.dados.values, color='blue', label='Preço Real')
        plt.plot(range(len(self.dados), len(self.dados) + dias_previsao), previsao_base, color='red', label='Previsão de Preço')

        # Plotar as simulações de Monte Carlo
        for sim in previsoes_mc:
            plt.plot(range(len(self.dados), len(self.dados) + dias_previsao), sim, color='gray', alpha=0.005)

        plt.title(f'Previsão de Preços para {self.ticker} com Monte Carlo')
        plt.xlabel('Data')
        plt.ylabel('Preço')
        plt.legend()
        plt.show()

def main(ticker, data_inicio, data_fim):
    # Criação do previsor de ações
    previsor = StockPredictor(ticker, data_inicio, data_fim)

    # Preprocessar dados e treinar o modelo
    X_train, y_train = previsor.preprocessar_dados()
    previsor.treinar_modelo(X_train, y_train)

    # Prever preços futuros e plotar os resultados com Monte Carlo
    previsor.plotar_previsao_com_mc(dias_previsao=60, num_simulacoes=1000)

if __name__ == "__main__":
    # Parâmetros de entrada
    ticker = 'EMBR3.SA'  # Substitua pelo ticker desejado
    data_inicio = '2023-01-02'
    data_fim = '2024-05-02'
    main(ticker, data_inicio, data_fim)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Epoch 1/20
# 3/3 [==============================] - 18s 2s/step - loss: 0.2161 - lr: 0.0010
# Epoch 2/20
# 3/3 [==============================] - 8s 2s/step - loss: 0.0370 - lr: 0.0010
# Epoch 3/20
# 3/3 [==============================] - 8s 2s/step - loss: 0.0246 - lr: 0.0010
# Epoch 4/20
# 3/3 [==============================] - 8s 3s/step - loss: 0.0162 - lr: 0.0010
# Epoch 5/20
# 3/3 [==============================] - 7s 2s/step - loss: 0.0127 - lr: 0.0010
# Epoch 6/20
# 3/3 [==============================] - 5s 2s/step - loss: 0.0105 - lr: 0.0010
# Epoch 7/20
# 3/3 [==============================] - 4s 1s/step - loss: 0.0072 - lr: 0.0010
# Epoch 8/20
# 3/3 [==============================] - 3s 796ms/step - loss: 0.0084 - lr: 0.0010
# Epoch 9/20
# 3/3 [==============================] - 3s 814ms/step - loss: 0.0050 - lr: 0.0010
# Epoch 10/20
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import yfinance as yf

# 1. Obter dados históricos
ticker = 'PETR4.SA'
start_date = '2010-01-01'
end_date = '2023-12-31'
data = yf.download(ticker, start=start_date, end=end_date)

# 2. Selecionar apenas o preço de fechamento ajustado
df = data[['Adj Close']]

# 3. Normalizar os dados
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df)

# 4. Dividir dados em treino e teste
train_size = int(len(scaled_data) * 0.8)
train_data = scaled_data[:train_size]
test_data = scaled_data[train_size:]

# 5. Preparar dados para LSTM
def create_dataset(data, time_step):
    X, Y = [], []
    for i in range(len(data) - time_step - 1):
        X.append(data[i:(i + time_step), 0])
        Y.append(data[i + time_step, 0])
    return np.array(X), np.array(Y)

time_step = 60  # Tamanho da janela de tempo
X_train, Y_train = create_dataset(train_data, time_step)
X_test, Y_test = create_dataset(test_data, time_step)

# 6. Reshape dos dados para LSTM [samples, time steps, features]
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# 7. Construir o modelo LSTM
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(time_step, 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')

# 8. Treinar o modelo
model.fit(X_train, Y_train, epochs=5, batch_size=32)

# 9. Fazer previsões
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)

# 10. Preparar dados de validação para plotagem
train = df[:train_size]
valid = df[train_size + time_step:]  # Ajuste para o tempo de atraso

# 11. Adicionar coluna de previsões ao dataframe de validação
valid['Predictions'] = np.nan
valid['Predictions'] = np.concatenate([np.zeros(len(valid) - len(predictions)), predictions.flatten()])  # Atribuição correta usando concatenação

# 12. Plotar resultados
plt.figure(figsize=(16, 8))
plt.title('Modelo LSTM para Predição de Preços - PETR4.SA')
plt.xlabel('Data')
plt.ylabel('Preço de Fechamento Ajustado')
plt.plot(train['Adj Close'])
plt.plot(valid[['Adj Close', 'Predictions']])
plt.legend(['Treino', 'Valores Reais', 'Predições'])
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Epoch 1/5
# 85/85 [==============================] - 11s 62ms/step - loss: 0.0015
# Epoch 2/5
# 85/85 [==============================] - 6s 68ms/step - loss: 4.1337e-04
# Epoch 3/5
# 85/85 [==============================] - 7s 78ms/step - loss: 3.3777e-04
# Epoch 4/5
# 85/85 [==============================] - 5s 63ms/step - loss: 2.9876e-04
# Epoch 5/5
# ...
# 20/20 [==============================] - 1s 20ms/step
# <ipython-input-10-c21f7fd2ff7f>:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = np.nan
# <ipython-input-10-c21f7fd2ff7f>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import yfinance as yf

# 1. Obter dados históricos
ticker = 'PETR4.SA'
start_date = '2010-01-01'
end_date = '2023-12-31'
data = yf.download(ticker, start=start_date, end=end_date)

# 2. Selecionar apenas o preço de fechamento ajustado
df = data[['Adj Close']]

# 3. Normalizar os dados
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df)

# 4. Dividir dados em treino e teste
train_size = int(len(scaled_data) * 0.8)
train_data = scaled_data[:train_size]
test_data = scaled_data[train_size:]

# 5. Preparar dados para LSTM
def create_dataset(data, time_step):
    X, Y = [], []
    for i in range(len(data) - time_step - 1):
        X.append(data[i:(i + time_step), 0])
        Y.append(data[i + time_step, 0])
    return np.array(X), np.array(Y)

time_step = 60  # Tamanho da janela de tempo
X_train, Y_train = create_dataset(train_data, time_step)
X_test, Y_test = create_dataset(test_data, time_step)

# 6. Reshape dos dados para LSTM [samples, time steps, features]
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# 7. Construir o modelo LSTM
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(time_step, 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')

# 8. Treinar o modelo
model.fit(X_train, Y_train, epochs=5, batch_size=32)

# 9. Fazer previsões
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)

# 10. Preparar dados de validação para plotagem
train = df[:train_size]
valid = df[train_size + time_step - 1:]  # Iniciar a partir do último preço dos dados de treino

# 11. Adicionar coluna de previsões ao dataframe de validação
valid['Predictions'] = np.nan
valid['Predictions'] = np.concatenate([np.zeros(len(valid) - len(predictions)), predictions.flatten()])  # Atribuição correta usando concatenação

# 12. Plotar resultados
plt.figure(figsize=(16, 8))
plt.title('Modelo LSTM para Predição de Preços - PETR4.SA')
plt.xlabel('Data')
plt.ylabel('Preço de Fechamento Ajustado')
plt.plot(train['Adj Close'])
plt.plot(valid[['Adj Close', 'Predictions']])
plt.legend(['Treino', 'Valores Reais', 'Predições'])
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Epoch 1/5
# 85/85 [==============================] - 10s 66ms/step - loss: 0.0017
# Epoch 2/5
# 85/85 [==============================] - 7s 78ms/step - loss: 3.9476e-04
# Epoch 3/5
# 85/85 [==============================] - 5s 64ms/step - loss: 3.3698e-04
# Epoch 4/5
# 85/85 [==============================] - 7s 82ms/step - loss: 3.2924e-04
# Epoch 5/5
# ...
# 20/20 [==============================] - 1s 19ms/step
# <ipython-input-11-b61485f64c71>:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = np.nan
# <ipython-input-11-b61485f64c71>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...
